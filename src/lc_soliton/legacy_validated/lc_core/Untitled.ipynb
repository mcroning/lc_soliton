# %%
# !grep -n "0.5.*::-1" ../legacy/lc_offload_tools.py
# !grep -n "enforce_x_symmetry" ../legacy/lc_offload_tools.py
# Out:
# 2171:        theta = 0.5 * (theta + theta[::-1, :])   ###temp
# 3164:        theta_seed = 0.5 * (theta_seed + theta_seed[::-1, :])
# 3166:        I_mid = 0.5 * (I_mid + I_mid[::-1, :])
# 3168:        tp = 0.5 * (tp + tp[::-1, :])
# 3170:        tn = 0.5 * (tn + tn[::-1, :])
